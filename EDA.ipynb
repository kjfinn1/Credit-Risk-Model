# %%
import pandas as pd 
import numpy as np 
import sklearn
import matplotlib 
import scipy

# %%
import zipfile
import os
from io import BytesIO

# %%
def read_csvs(folder_path):

    for filename in os.listdir(folder_path):
        if filename.endswith('.csv'):

            name = os.path.splitext(filename)[0]

            file_path = os.path.join(folder_path, filename)
            df = pd.read_csv(file_path)

            globals()[name] = df

# %%
file_path = '/Users/kevinfinn/Documents/csv_files/train'
dataframes = read_csvs(file_path)
# Out:
# /var/folders/l2/yg146pls5_q015mz26q0pyfm0000gn/T/ipykernel_96116/4238755053.py:9: DtypeWarning: Columns (20,45,46,56,57,84,143,146,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/l2/yg146pls5_q015mz26q0pyfm0000gn/T/ipykernel_96116/4238755053.py:9: DtypeWarning: Columns (20,45,46,53,57,84,143,146,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/l2/yg146pls5_q015mz26q0pyfm0000gn/T/ipykernel_96116/4238755053.py:9: DtypeWarning: Columns (1,2,3,4,7,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/l2/yg146pls5_q015mz26q0pyfm0000gn/T/ipykernel_96116/4238755053.py:9: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/l2/yg146pls5_q015mz26q0pyfm0000gn/T/ipykernel_96116/4238755053.py:9: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/l2/yg146pls5_q015mz26q0pyfm0000gn/T/ipykernel_96116/4238755053.py:9: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/l2/yg146pls5_q015mz26q0pyfm0000gn/T/ipykernel_96116/4238755053.py:9: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/l2/yg146pls5_q015mz26q0pyfm0000gn/T/ipykernel_96116/4238755053.py:9: DtypeWarning: Columns (11,12,14,30,44,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
train_applprev_1_0
# Out:
#          case_id  actualdpd_943P  annuity_853A approvaldate_319D  \
# 0              2             0.0         640.2               NaN
# 1              2             0.0        1682.4               NaN
# 2              3             0.0        6140.0               NaN
# 3              4             0.0        2556.6               NaN
# 4              5             0.0           NaN               NaN
# ...          ...             ...           ...               ...
# 3887679  2651092             0.0        3000.0        2019-12-30
# 3887680  2651092             0.0        3119.2        2012-12-12
# 3887681  2651092             0.0        4366.0        2017-11-09
# 3887682  2651092             0.0        4496.6        2019-02-17
# 3887683  2651092             0.0           NaN        2014-02-15
#
#          byoccupationinc_3656910L cancelreason_3545846M  childnum_21L  \
# 0                             NaN              a55475b1           0.0
# 1                             NaN              a55475b1           0.0
# 2                             NaN           P94_109_143           NaN
# 3                             NaN             P24_27_36           NaN
# 4                             NaN           P85_114_140           NaN
# ...                           ...                   ...           ...
# 3887679                       NaN              a55475b1           NaN
# 3887680                   25000.0              a55475b1           1.0
# 3887681                       NaN              a55475b1           NaN
# 3887682                       NaN              a55475b1           NaN
# 3887683                   60000.0              a55475b1           1.0
#
#         creationdate_885D  credacc_actualbalance_314A  credacc_credlmt_575A  \
# 0              2013-04-03                         NaN                   0.0
# 1              2013-04-03                         NaN                   0.0
# 2              2019-01-07                         NaN                   0.0
# 3              2019-01-08                         NaN                   0.0
# 4              2019-01-16                         NaN                   NaN
# ...                   ...                         ...                   ...
# 3887679        2019-12-30                     53300.0               53300.0
# 3887680        2012-12-12                         NaN                   0.0
# 3887681        2017-11-09                         NaN                   0.0
# 3887682        2019-02-17                         NaN                   0.0
# 3887683        2014-02-15                         NaN               53300.0
#
#          ...  num_group1  outstandingdebt_522A pmtnum_8L  postype_4733339M  \
# 0        ...           0                   NaN      24.0          a55475b1
# 1        ...           1                   NaN      12.0          a55475b1
# 2        ...           0                   NaN      12.0          a55475b1
# 3        ...           0                   NaN      24.0          a55475b1
# 4        ...           0                   NaN       NaN          a55475b1
# ...      ...         ...                   ...       ...               ...
# 3887679  ...           0               53998.0      18.0      P177_117_192
# 3887680  ...           7                   0.0      12.0       P149_40_170
# 3887681  ...           4                   0.0       5.0       P60_146_156
# 3887682  ...           2                   0.0       6.0       P149_40_170
# 3887683  ...           6                   0.0       NaN        P46_145_78
#
#          profession_152M rejectreason_755M  rejectreasonclient_4145042M  \
# 0               a55475b1          a55475b1                     a55475b1
# 1               a55475b1          a55475b1                     a55475b1
# 2               a55475b1       P94_109_143                     a55475b1
# 3               a55475b1          a55475b1                     a55475b1
# 4               a55475b1          a55475b1                     a55475b1
# ...                  ...               ...                          ...
# 3887679         a55475b1          a55475b1                     a55475b1
# 3887680         a55475b1          a55475b1                     a55475b1
# 3887681         a55475b1          a55475b1                     a55475b1
# 3887682         a55475b1          a55475b1                     a55475b1
# 3887683         a55475b1          a55475b1                     a55475b1
#
#         revolvingaccount_394A status_219L  tenor_203L
# 0                         NaN           D        24.0
# 1                         NaN           D        12.0
# 2                         NaN           D        12.0
# 3                         NaN           T        24.0
# 4                         NaN           T         NaN
# ...                       ...         ...         ...
# 3887679                   NaN           N        18.0
# 3887680                   NaN           K        12.0
# 3887681                   NaN           K         5.0
# 3887682                   NaN           K         6.0
# 3887683           680531000.0           K         NaN
#
# [3887684 rows x 41 columns]
